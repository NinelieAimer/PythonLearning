# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('E:\\learning\\spssModelerLearning\\tantannic\\titanic_train .csv')

# %%
df=pd.read_csv(filepath_or_buffer='E:\\learning\\spssModelerLearning\\tantannic\\titanic_train .csv',index_col='PassengerId')

# %%
df=pd.read_csv('C:\\Users\\57206\\Desktop\\000905.csv',
               encoding='gbk')

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>行标签</th>
#       <th>平均值项:收盘价</th>
#       <th>Unnamed: 2</th>
#       <th>Unnamed: 3</th>
#       <th>Unnamed: 4</th>
#       <th>Unnamed: 5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018/1/2</td>
#       <td>6332.22690</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018/1/3</td>
#       <td>6388.25330</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018/1/4</td>
#       <td>6417.53500</td>
# ...

# %%
df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>行标签</th>
#       <th>平均值项:收盘价</th>
#       <th>Unnamed: 2</th>
#       <th>Unnamed: 3</th>
#       <th>Unnamed: 4</th>
#       <th>Unnamed: 5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018/1/2</td>
#       <td>6332.2269</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018/1/3</td>
#       <td>6388.2533</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018/1/4</td>
#       <td>6417.5350</td>
# ...

# %%
df=df.iloc[:,0:2]

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>行标签</th>
#       <th>平均值项:收盘价</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018/1/2</td>
#       <td>6332.22690</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018/1/3</td>
#       <td>6388.25330</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018/1/4</td>
#       <td>6417.53500</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2018/1/5</td>
#       <td>6417.25370</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2018/1/8</td>
#       <td>6446.18180</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2018/1/9</td>
# ...

# %%
df.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>平均值项:收盘价</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>323.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>5235.897840</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>704.797338</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>4018.461400</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>4559.104900</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>5195.200200</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>5891.059900</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>6446.181800</td>
# ...

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>行标签</th>
#       <th>平均值项:收盘价</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018/1/2</td>
#       <td>6332.22690</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018/1/3</td>
#       <td>6388.25330</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018/1/4</td>
#       <td>6417.53500</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2018/1/5</td>
#       <td>6417.25370</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2018/1/8</td>
#       <td>6446.18180</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2018/1/9</td>
# ...

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>行标签</th>
#       <th>平均值项:收盘价</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018/1/2</td>
#       <td>6332.22690</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018/1/3</td>
#       <td>6388.25330</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018/1/4</td>
#       <td>6417.53500</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2018/1/5</td>
#       <td>6417.25370</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2018/1/8</td>
#       <td>6446.18180</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2018/1/9</td>
# ...

# %%
df.rename({'行标签':'date',
           '平均值项:收盘价':'price'})
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>行标签</th>
#       <th>平均值项:收盘价</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018/1/2</td>
#       <td>6332.22690</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018/1/3</td>
#       <td>6388.25330</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018/1/4</td>
#       <td>6417.53500</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2018/1/5</td>
#       <td>6417.25370</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2018/1/8</td>
#       <td>6446.18180</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2018/1/9</td>
# ...

# %%
df.columns=['date','price']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=323, step=1)

# %%
df.columns
# Out:
# Index(['date', 'price'], dtype='object')

# %%
xls=pd.read_excel('C:\\Users\\57206\\Desktop\\test.xlsx')

# %%
xls
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018-01-02 00:00:00</td>
#       <td>6332.22690</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018-01-03 00:00:00</td>
#       <td>6388.25330</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018-01-04 00:00:00</td>
#       <td>6417.53500</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2018-01-05 00:00:00</td>
#       <td>6417.25370</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2018-01-08 00:00:00</td>
#       <td>6446.18180</td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %%
xls.var()
# Out:
# price    496739.288095
# dtype: float64

# %%
xls
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018-01-02 00:00:00</td>
#       <td>6332.22690</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018-01-03 00:00:00</td>
#       <td>6388.25330</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018-01-04 00:00:00</td>
#       <td>6417.53500</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2018-01-05 00:00:00</td>
#       <td>6417.25370</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2018-01-08 00:00:00</td>
#       <td>6446.18180</td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %%
import numpy as np
import pandas as pd

# %%
data=pd.Series(np.random.randn(9),index=[
    ['a','a','a','b','b','c','c','d','d'],
    [1,2,3,1,3,1,2,2,3]
])

# %%
data
# Out:
# a  1    0.302343
#    2   -0.247178
#    3    0.915256
# b  1    0.383245
#    3   -1.082797
# c  1   -0.212644
#    2   -1.678298
# d  2   -1.073515
#    3    2.350983
# dtype: float64

# %%
data.index
# Out:
# MultiIndex(levels=[['a', 'b', 'c', 'd'], [1, 2, 3]],
#            labels=[[0, 0, 0, 1, 1, 2, 2, 3, 3], [0, 1, 2, 0, 2, 0, 1, 1, 2]])

# %%
data.loc['b':'c',2:3]
# Out:
# b  3   -1.082797
# c  2   -1.678298
# dtype: float64

# %%
frame=pd.DataFrame(
    np.arange(12).reshape((4,3)),
    index=[['a','a','b','b'],[1,2,1,2]],
    columns=[
        ['kirito','kirito','asuna'],
        ['green','red','blue']
    ]
)

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.index.names=['key1','key2']
frame.columns.names=['name','color']

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>color</th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.swaplevel('key1','key2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexes\multi.py in _get_level_number(self, level)
#     615                                  'level number' % level)
# --> 616             level = self.names.index(level)
#     617         except ValueError:
#
# ValueError: 'name' is not in list
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-4d1b5b326fc9> in <module>()
# ----> 1 frame.swaplevel('name','color')
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\frame.py in swaplevel(self, i, j, axis)
#    3403         axis = self._get_axis_number(axis)
#    3404         if axis == 0:
# -> 3405             result.index = result.index.swaplevel(i, j)
#    3406         else:
#    3407             result.columns = result.columns.swaplevel(i, j)
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexes\multi.py in swaplevel(self, i, j)
#    1618         new_names = list(self.names)
#    1619
# -> 1620         i = self._get_level_number(i)
#    1621         j = self._get_level_number(j)
#    1622
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexes\multi.py in _get_level_number(self, level)
#     617         except ValueError:
#     618             if not isinstance(level, int):
# --> 619                 raise KeyError('Level %s not found' % str(level))
#     620             elif level < 0:
#     621                 level += self.nlevels
#
# KeyError: 'Level name not found'

# %%
import numpy as np
import pandas as pd

# %%
frame=pd.DataFrame(
    np.arange(12).reshape((4,3)),
    index=[['a','a','b','b'],[1,2,1,2]],
    columns=[
        ['kirito','kirito','asuna'],
        ['green','red','blue']
    ]
)

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.index.names=['key1','key2']

# %%
frame.columns.names=['name','color']

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>color</th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.sort_index(level=1)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>color</th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>a</th>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>color</th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.sum(level=1)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th>color</th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>6</td>
#       <td>8</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>12</td>
#       <td>14</td>
#       <td>16</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>color</th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>color</th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>color</th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>color</th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.loc[:,1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [1] is not in the [columns]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-ca9a80e43faa> in <module>()
# ----> 1 frame.loc[:,1]
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     834     def _getitem_tuple(self, tup):
#     835         try:
# --> 836             return self._getitem_lowerdim(tup)
#     837         except IndexingError:
#     838             pass
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     946         # we may have a nested tuples indexer here
#     947         if self._is_nested_tuple_indexer(tup):
# --> 948             return self._getitem_nested_tuple(tup)
#     949
#     950         # we maybe be using a tuple to represent multiple dimensions here
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexing.py in _getitem_nested_tuple(self, tup)
#    1021
#    1022             current_ndim = obj.ndim
# -> 1023             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1024             axis += 1
#    1025
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1440                 raise
#    1441             except:
# -> 1442                 error()
#    1443
#    1444         return True
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexing.py in error()
#    1427                                     "key")
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#    1431             try:
#
# KeyError: 'the label [1] is not in the [columns]'

# %%
frame.loc['a',1]
# Out:
# name    color
# kirito  green    0
#         red      1
# asuna   blue     2
# Name: (a, 1), dtype: int32

# %%
frame.sum(level='key1')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th>color</th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>3</td>
#       <td>5</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>15</td>
#       <td>17</td>
#       <td>19</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>color</th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.index
# Out:
# MultiIndex(levels=[['a', 'b'], [1, 2]],
#            labels=[[0, 0, 1, 1], [0, 1, 0, 1]],
#            names=['key1', 'key2'])

# %%
frame.rename({
    "red":"green"
})
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>color</th>
#       <th>green</th>
#       <th>red</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.rename_axis({"red":"green"},axis=1)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>color</th>
#       <th>green</th>
#       <th>green</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame=frame.rename_axis({"red":"green"},axis=1)

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="2" halign="left">kirito</th>
#       <th>asuna</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>color</th>
#       <th>green</th>
#       <th>green</th>
#       <th>blue</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.sum(level='color',axis=1)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>color</th>
#       <th>blue</th>
#       <th>green</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>8</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>11</td>
#       <td>19</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame=pd.DataFrame({
    'a':range(7),
    'b':range(7,0,-1),
    'c':['one','one','one','two','two','two','two'],
    'd':[0,1,2,0,1,2,3]
})

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>7</td>
#       <td>one</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>6</td>
#       <td>one</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>5</td>
#       <td>one</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>4</td>
#       <td>two</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>3</td>
#       <td>two</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>2</td>
#       <td>two</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>1</td>
#       <td>two</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.set_index(['c','d'])
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#     <tr>
#       <th>c</th>
#       <th>d</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">one</th>
#       <th>0</th>
#       <td>0</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">two</th>
#       <th>0</th>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.set_index(['c','d'],drop=False)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#     <tr>
#       <th>c</th>
#       <th>d</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">one</th>
#       <th>0</th>
#       <td>0</td>
#       <td>7</td>
#       <td>one</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>6</td>
#       <td>one</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>5</td>
#       <td>one</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">two</th>
#       <th>0</th>
#       <td>3</td>
#       <td>4</td>
#       <td>two</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>3</td>
#       <td>two</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>2</td>
#       <td>two</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>1</td>
#       <td>two</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame=frame.set_index(['c','d'],drop=False)

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#     <tr>
#       <th>c</th>
#       <th>d</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">one</th>
#       <th>0</th>
#       <td>0</td>
#       <td>7</td>
#       <td>one</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>6</td>
#       <td>one</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>5</td>
#       <td>one</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">two</th>
#       <th>0</th>
#       <td>3</td>
#       <td>4</td>
#       <td>two</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>3</td>
#       <td>two</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>2</td>
#       <td>two</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>1</td>
#       <td>two</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#     <tr>
#       <th>c</th>
#       <th>d</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">one</th>
#       <th>0</th>
#       <td>0</td>
#       <td>7</td>
#       <td>one</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>6</td>
#       <td>one</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>5</td>
#       <td>one</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">two</th>
#       <th>0</th>
#       <td>3</td>
#       <td>4</td>
#       <td>two</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>3</td>
#       <td>two</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>2</td>
#       <td>two</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>1</td>
#       <td>two</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.index
# Out:
# MultiIndex(levels=[['one', 'two'], [0, 1, 2, 3]],
#            labels=[[0, 0, 0, 1, 1, 1, 1], [0, 1, 2, 0, 1, 2, 3]],
#            names=['c', 'd'])

# %%
frame['one']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'one'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-d9192ee498dc> in <module>()
# ----> 1 frame['one']
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'one'

# %%
frame=pd.DataFrame({
    'a':range(7),
    'b':range(7,0,-1),
    'c':['one','one','one','two','two','two','two'],
    'd':[0,1,2,0,1,2,3]
})

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>7</td>
#       <td>one</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>6</td>
#       <td>one</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>5</td>
#       <td>one</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>4</td>
#       <td>two</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>3</td>
#       <td>two</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>2</td>
#       <td>two</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>1</td>
#       <td>two</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>7</td>
#       <td>one</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>6</td>
#       <td>one</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>5</td>
#       <td>one</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>4</td>
#       <td>two</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>3</td>
#       <td>two</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>2</td>
#       <td>two</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>1</td>
#       <td>two</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame=frame.set_index(['c','d'])

# %%
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#     <tr>
#       <th>c</th>
#       <th>d</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">one</th>
#       <th>0</th>
#       <td>0</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">two</th>
#       <th>0</th>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.loc['one','a':'b']
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#     <tr>
#       <th>d</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1=pd.DataFrame({
    'key':['b','b','a','c','a','a','b'],
    'data1':range(7)
})

# %%
df2=pd.DataFrame(
    {
        'key':['a','b','d'],
        'data2':range(3)
    }
)

# %%
pd.merge(df1,df2,on=['key'])
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data1</th>
#       <th>key</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>b</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>b</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>b</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>a</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>a</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>a</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.merge(df1,df2,on='key',how='outer')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data1</th>
#       <th>key</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>b</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>b</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6.0</td>
#       <td>b</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.0</td>
#       <td>a</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.0</td>
#       <td>a</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.0</td>
#       <td>a</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>3.0</td>
#       <td>c</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>NaN</td>
#       <td>d</td>
#       <td>2.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df3=pd.DataFrame({
    'lkey':['b','b','a','c','a','a','b'],
    'data1':range(7)
})

# %%
df4=pd.DataFrame(
    {
        'rkey':['a','b','c'],
        'data2':range(3)
    }
)

# %%
pd.merge(df3,df4,left_on='lkey',right_on='rkey')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data1</th>
#       <th>lkey</th>
#       <th>data2</th>
#       <th>rkey</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>b</td>
#       <td>1</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>b</td>
#       <td>1</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>b</td>
#       <td>1</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>a</td>
#       <td>0</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>a</td>
#       <td>0</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>a</td>
#       <td>0</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>3</td>
#       <td>c</td>
#       <td>2</td>
#       <td>c</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1=pd.DataFrame({
    'key':['b','b','a','c','a','b'],
    'data1':range(6)
})

# %%
df2=pd.DataFrame({
    'key':['a','b','a','b','d'],
    'data2':range(5)
})

# %%
pd.merge(df1,df2,how='left')
# Out:
#   File "<ipython-input-121-4348262a3216>", line 1
#     pd.merge(df1,df2,how='left',left_index)
#                                ^
# SyntaxError: positional argument follows keyword argument

# %%
df1.sort_values('data1',ascending=False)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data1</th>
#       <th>key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>c</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>b</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
left=pd.DataFrame({
    'key1':['foo','foo','bar'],
    'key2':['one','two','one'],
    'lval':[1,2,3]
})

# %%
right=pd.DataFrame({
    'key1':['foo','foo','bar','bar'],
    'key2':['one','one','one','two'],
    'rval':[4,5,6,7]
})

# %%
pd.merge(left,right,on='key1',suffixes=['_left','_right'])
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key1</th>
#       <th>key2_left</th>
#       <th>lval</th>
#       <th>key2_right</th>
#       <th>rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>foo</td>
#       <td>one</td>
#       <td>1</td>
#       <td>one</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>foo</td>
#       <td>one</td>
#       <td>1</td>
#       <td>one</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>foo</td>
#       <td>two</td>
#       <td>2</td>
#       <td>one</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>foo</td>
#       <td>two</td>
#       <td>2</td>
#       <td>one</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>bar</td>
#       <td>one</td>
#       <td>3</td>
#       <td>one</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>bar</td>
#       <td>one</td>
#       <td>3</td>
#       <td>two</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
left1=pd.DataFrame({
    'key':['a','b','a','a','b','c'],
    'value':range(6)
})

# %%
right1=pd.DataFrame({
    'group_val':[3.5,7],
},index=['a','b'])

# %%
left1
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>a</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>b</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>c</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
right1
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>group_val</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>3.5</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>7.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.merge(left1,right1,left_on='key',right_index=True)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#       <th>group_val</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a</td>
#       <td>0</td>
#       <td>3.5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#       <td>2</td>
#       <td>3.5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>a</td>
#       <td>3</td>
#       <td>3.5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>b</td>
#       <td>4</td>
#       <td>7.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
left1=pd.DataFrame({
    'key1':['Ohio','Ohio','Ohio','Nevada','Nevada'],
    'key2':[2000,2001,2002,2001,2002],
    'data':np.arange(5)
})

# %%
right1=pd.DataFrame(np.arange(12).reshape((6,2)),
                    index=[['Nevada','Nevada','Ohio','Ohio','Ohio','Ohio'],[2001,2000,2000,2000,2001,2002]],
                    columns=['event1','event2'])

# %%
left1
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data</th>
#       <th>key1</th>
#       <th>key2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Ohio</td>
#       <td>2000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Ohio</td>
#       <td>2001</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>Ohio</td>
#       <td>2002</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>Nevada</td>
#       <td>2001</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>Nevada</td>
#       <td>2002</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
right1
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>event1</th>
#       <th>event2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">Nevada</th>
#       <th>2001</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2000</th>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">Ohio</th>
#       <th>2000</th>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2000</th>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2001</th>
#       <td>8</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>2002</th>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.merge(left1,right1,left_on=['key1','key2'],right_index=True,how='outer')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data</th>
#       <th>key1</th>
#       <th>key2</th>
#       <th>event1</th>
#       <th>event2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>Ohio</td>
#       <td>2000</td>
#       <td>4.0</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>Ohio</td>
#       <td>2000</td>
#       <td>6.0</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>Ohio</td>
#       <td>2001</td>
#       <td>8.0</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2.0</td>
#       <td>Ohio</td>
#       <td>2002</td>
#       <td>10.0</td>
#       <td>11.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.0</td>
#       <td>Nevada</td>
#       <td>2001</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.0</td>
#       <td>Nevada</td>
#       <td>2002</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>Nevada</td>
#       <td>2000</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
s1=pd.Series([0,1],index=['a','b'])

# %%
s2=pd.Series([2,3,4],index=['a','d','e'])

# %%
s3=pd.Series([5,6],index=['f','g'])

# %%
pd.concat([s1,s2])
# Out:
# a    0
# b    1
# a    2
# d    3
# e    4
# dtype: int64

# %%
pd.concat([s1,s2],axis=1,join='inner')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>0</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.concat([s1,s2,s3],keys=['one','two','three'])
# Out:
# one    a    0
#        b    1
# two    a    2
#        d    3
#        e    4
# three  f    5
#        g    6
# dtype: int64

# %%
df1=pd.DataFrame(np.arange(6).reshape((3,2)),index=['a','b','c'],columns=['one','two'])
df2=pd.DataFrame(5+np.arange(4).reshape((2,2)),index=['a','c'],columns=['three','four'])

# %%
pd.concat([df1,df2])
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>four</th>
#       <th>one</th>
#       <th>three</th>
#       <th>two</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>NaN</td>
#       <td>2.0</td>
#       <td>NaN</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>NaN</td>
#       <td>4.0</td>
#       <td>NaN</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>a</th>
#       <td>6.0</td>
#       <td>NaN</td>
#       <td>5.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>8.0</td>
#       <td>NaN</td>
#       <td>7.0</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.concat([df1,df2],axis=1,keys=['level1','level2'])
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">level1</th>
#       <th colspan="2" halign="left">level2</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>four</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>0</td>
#       <td>1</td>
#       <td>5.0</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>2</td>
#       <td>3</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>4</td>
#       <td>5</td>
#       <td>7.0</td>
#       <td>8.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1=pd.DataFrame(np.random.randn(3,4),columns=['a','b','c','d'])
df2=pd.DataFrame(np.random.randn(2,3),columns=['b','d','a'])

# %%
pd.concat([df1,df2],axis=0,keys=['level1','level2'],ignore_index=True)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.275693</td>
#       <td>0.357728</td>
#       <td>0.022455</td>
#       <td>-0.133544</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.488277</td>
#       <td>-0.674829</td>
#       <td>1.331353</td>
#       <td>-0.517763</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.766748</td>
#       <td>1.285256</td>
#       <td>-0.335276</td>
#       <td>-2.747144</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.364019</td>
#       <td>0.761009</td>
#       <td>NaN</td>
#       <td>1.670232</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.613397</td>
#       <td>-0.016521</td>
#       <td>NaN</td>
#       <td>-1.071659</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1=pd.DataFrame(
    {
        'a':[1,np.NAN,5,np.NAN],
        'b':[np.NAN,2,np.NAN,6],
        'c':range(2,18,4)
    }
)
df2=pd.DataFrame(
    {
        'a':[5,4,np.NAN,3,7],
        'b':[np.NAN,3,44,6,8]
    }
)

# %%
df1.combine_first(df2)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>NaN</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.0</td>
#       <td>2.0</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.0</td>
#       <td>44.0</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.0</td>
#       <td>6.0</td>
#       <td>14.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7.0</td>
#       <td>8.0</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data=pd.DataFrame(np.arange(6).reshape((2,3)),
                  index=['Ohio','Colorado'],
                  columns=['one','two','three'],
                  )

# %%
data.index.name='state'

# %%
data.columns.name='number'

# %%
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>number</th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#     </tr>
#     <tr>
#       <th>state</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ohio</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Colorado</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
result=data.stack('number')

# %%
result.unstack('state')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>state</th>
#       <th>Ohio</th>
#       <th>Colorado</th>
#     </tr>
#     <tr>
#       <th>number</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>one</th>
#       <td>0</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>1</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>three</th>
#       <td>2</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
s1=pd.Series([0,1,2,3],index=['a','b','c','d'])
s2=pd.Series([4,5,6],index=['c','d','e'])
test=pd.concat([s1,s2],keys=['one','two'])

# %%
test
# Out:
# one  a    0
#      b    1
#      c    2
#      d    3
# two  c    4
#      d    5
#      e    6
# dtype: int64

# %%
test.unstack()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>e</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>one</th>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.0</td>
#       <td>5.0</td>
#       <td>6.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df=pd.DataFrame({
    'left':result,'right':result+5
})

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>left</th>
#       <th>right</th>
#     </tr>
#     <tr>
#       <th>state</th>
#       <th>number</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">Ohio</th>
#       <th>one</th>
#       <td>0</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>three</th>
#       <td>2</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">Colorado</th>
#       <th>one</th>
#       <td>3</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>4</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>three</th>
#       <td>5</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
rest=df.unstack()

# %%
rest.columns.names=['turn','number']

# %%
rest
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>turn</th>
#       <th colspan="3" halign="left">left</th>
#       <th colspan="3" halign="left">right</th>
#     </tr>
#     <tr>
#       <th>number</th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#     </tr>
#     <tr>
#       <th>state</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ohio</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Colorado</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
rest.swaplevel('turn','number',axis=1)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>number</th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#     </tr>
#     <tr>
#       <th>turn</th>
#       <th>left</th>
#       <th>left</th>
#       <th>left</th>
#       <th>right</th>
#       <th>right</th>
#       <th>right</th>
#     </tr>
#     <tr>
#       <th>state</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ohio</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Colorado</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import numpy as np
import pandas as pd

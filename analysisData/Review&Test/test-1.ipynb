# %%
import matplotlib

# %%
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
df=pd.read_table('E:\\learning\\PythonLearning\\analysisData\\Review&Test\\DRUG.txt',sep=',')

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Sex</th>
#       <th>BP</th>
#       <th>Cholesterol</th>
#       <th>Na</th>
#       <th>K</th>
#       <th>Drug</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>23</td>
#       <td>F</td>
#       <td>HIGH</td>
#       <td>HIGH</td>
#       <td>0.792535</td>
#       <td>0.031258</td>
#       <td>drugY</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>47</td>
#       <td>M</td>
#       <td>LOW</td>
#       <td>HIGH</td>
#       <td>0.739309</td>
#       <td>0.056468</td>
#       <td>drugC</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Sex</th>
#       <th>BP</th>
#       <th>Cholesterol</th>
#       <th>Na</th>
#       <th>K</th>
#       <th>Drug</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>23</td>
#       <td>F</td>
#       <td>HIGH</td>
#       <td>HIGH</td>
#       <td>0.792535</td>
#       <td>0.031258</td>
#       <td>drugY</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>47</td>
#       <td>M</td>
#       <td>LOW</td>
#       <td>HIGH</td>
#       <td>0.739309</td>
#       <td>0.056468</td>
#       <td>drugC</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Na</th>
#       <th>K</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>44.315000</td>
#       <td>0.697095</td>
#       <td>0.050174</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>16.544315</td>
#       <td>0.118907</td>
#       <td>0.017611</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>15.000000</td>
#       <td>0.500169</td>
#       <td>0.020022</td>
#     </tr>
#     <tr>
#       <th>25%</th>
# ...

# %%
df_Age=df['Age']

# %%
df_cut_age=pd.cut(df_Age,4,labels=['child','young','man','old'])

# %%
df_cut_age
# Out:
# 0      child
# 1        man
# 2        man
# 3      child
# 4        old
# 5      child
# 6        man
# 7      young
# 8        old
# 9      young
# 10       man
# 11     young
# 12     young
# 13       old
# 14       man
# 15     child
# 16       old
# 17     young
# 18     child
# 19     young
# 20       man
# 21       old
# 22       man
# 23       man
# 24     young
# 25     child
# 26     young
# 27       man
# 28     young
# 29       man
#        ...
# 170    child
# 171      man
# 172    young
# 173    young
# 174    young
# 175      old
# 176      man
# 177    child
# 178    young
# 179      old
# 180    child
# 181      man
# 182    child
# 183    young
# 184    child
# 185      man
# 186      old
# 187      man
# 188      old
# 189      old
# 190      man
# 191    child
# 192      old
# 193      old
# 194      man
# 195      man
# 196    child
# 197      man
# 198    child
# 199    young
# Name: Age, Length: 200, dtype: category
# ...

# %%
df.groupby(df_cut_age).mean()[['Na','K']].plot.bar()

# %%
NaK=df['Na']/df['K']

# %%
df['Na/K']=NaK

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Sex</th>
#       <th>BP</th>
#       <th>Cholesterol</th>
#       <th>Na</th>
#       <th>K</th>
#       <th>Drug</th>
#       <th>Na/K</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>23</td>
#       <td>F</td>
#       <td>HIGH</td>
#       <td>HIGH</td>
#       <td>0.792535</td>
#       <td>0.031258</td>
#       <td>drugY</td>
#       <td>25.354629</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>47</td>
#       <td>M</td>
#       <td>LOW</td>
#       <td>HIGH</td>
#       <td>0.739309</td>
#       <td>0.056468</td>
#       <td>drugC</td>
# ...

# %%
df['Na/K'].plot()

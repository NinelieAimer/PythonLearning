# %%
import numpy as np
import pandas as pd
from numpy import nan as NA

# %%
series=pd.Series(['kirito','asuna',NA,'xilika'])

# %%
series
# Out:
# 0    kirito
# 1     asuna
# 2       NaN
# 3    xilika
# dtype: object

# %%
series.dropna()
# Out:
# 0    kirito
# 1     asuna
# 3    xilika
# dtype: object

# %%
series
# Out:
# 0    kirito
# 1     asuna
# 2       NaN
# 3    xilika
# dtype: object

# %%
df=pd.DataFrame([
    [1,2,3],[1,NA,NA],[NA,NA,NA],[NA,6.5,3]
])

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.dropna()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.dropna(axis=1)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#     </tr>
#     <tr>
#       <th>1</th>
#     </tr>
#     <tr>
#       <th>2</th>
#     </tr>
#     <tr>
#       <th>3</th>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.dropna(how='all')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.fillna(0)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.fillna({0:0,1:1,2:2},inplace=True)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.iloc[:,0:1]=NA

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.iloc[0]=1

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.fillna(method='ffill')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.0</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.iloc[:,0:1]=NA

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.fillna({0:1})
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.0</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.iloc[1:,0:1]=NA

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.iloc[0,0]=1

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.fillna(method='ffill')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.0</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df=pd.DataFrame({
    'k1':['one','two']*3+['two'],
    'k2':[1,1,2,3,3,4,4]
})

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>k1</th>
#       <th>k2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>one</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>two</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>one</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>two</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>one</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>two</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>two</td>
#       <td>4</td>
# ...

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>k1</th>
#       <th>k2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>one</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>two</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>one</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>two</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>one</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>two</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>k1</th>
#       <th>k2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>one</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>two</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>one</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>two</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>one</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>two</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>two</td>
#       <td>4</td>
# ...

# %%
df=pd.DataFrame({
    'name':['Pandas','']
})

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Pandas</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.applymap(lambda x:x.lower())
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>pandas</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df=pd.DataFrame(
    {
        'name':['Kirito','Asuna','Xilika'],
        'age':[16,17,22]
    }
)

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16</td>
#       <td>Kirito</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>17</td>
#       <td>Asuna</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>22</td>
#       <td>Xilika</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.loc[:,'age']=[16,17,22]

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16</td>
#       <td>Kirito</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>17</td>
#       <td>Asuna</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>22</td>
#       <td>Xilika</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16</td>
#       <td>Kirito</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>17</td>
#       <td>Asuna</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>22</td>
#       <td>Xilika</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.loc[:,'age']=[1,2,3]

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kirito</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Asuna</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Xilika</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kirito</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Asuna</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Xilika</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
test=df['age'].map({
    1:'spss',
    2:'sas',
    3:'python'
})

# %%
age=df['age']

# %%
age=test

# %%
df['age']=age

# %%
import pandas as pd
import numpy as np

# %%
data=pd.DataFrame(
    np.arange(12).reshape((3,4)),
    index=['kirito','asuna','sikuha'],
    columns=['age','size','tall','height']
)

# %%
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>size</th>
#       <th>tall</th>
#       <th>height</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>kirito</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>asuna</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>sikuha</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
new_index=data.index.map(lambda x:x.upper())

# %%
new_index
# Out:
# Index(['KIRITO', 'ASUNA', 'SIKUHA'], dtype='object')

# %%
data.index=new_index

# %%
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>size</th>
#       <th>tall</th>
#       <th>height</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>KIRITO</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>ASUNA</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>SIKUHA</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data.rename(
    index={
        'KIRITO':'kirito'
    },
    columns={
        'age':"names"
    }
)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>names</th>
#       <th>size</th>
#       <th>tall</th>
#       <th>height</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>kirito</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>ASUNA</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>SIKUHA</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>size</th>
#       <th>tall</th>
#       <th>height</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>KIRITO</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>ASUNA</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>SIKUHA</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ages=[20,22,25,27,21,23,37,31,61,45,41,32]
bins=[18,25,35,60,100]

# %%
cats=pd.cut(ages,bins,labels=['name','time','come','slim'])

# %%
cats
# Out:
# [name, name, name, time, name, ..., time, slim, come, come, time]
# Length: 12
# Categories (4, object): [name < time < come < slim]

# %%
cats.codes
# Out:
# array([0, 0, 0, 1, 0, 0, 2, 1, 3, 2, 2, 1], dtype=int8)

# %%
cats.categories
# Out:
# Index(['name', 'time', 'come', 'slim'], dtype='object')

# %%
pd.value_counts(cats)
# Out:
# name    5
# come    3
# time    3
# slim    1
# dtype: int64

# %%
data=pd.cut(np.random.rand(20),4,precision=3)

# %%
data
# Out:
# [(0.253, 0.498], (0.253, 0.498], (0.498, 0.744], (0.498, 0.744], (0.744, 0.989], ..., (0.00624, 0.253], (0.253, 0.498], (0.00624, 0.253], (0.498, 0.744], (0.00624, 0.253]]
# Length: 20
# Categories (4, interval[float64]): [(0.00624, 0.253] < (0.253, 0.498] < (0.498, 0.744] < (0.744, 0.989]]

# %%
data=pd.DataFrame(np.random.randn(1000,4))

# %%
data.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>1000.000000</td>
#       <td>1000.000000</td>
#       <td>1000.000000</td>
#       <td>1000.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>-0.028885</td>
#       <td>-0.049356</td>
#       <td>0.033303</td>
#       <td>-0.027339</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.969265</td>
#       <td>1.007872</td>
#       <td>1.020944</td>
#       <td>0.990272</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>-2.869856</td>
# ...

# %%
col=data.loc[:,2]

# %%
col
# Out:
# 0     -0.711325
# 1      1.052716
# 2     -1.113992
# 3     -1.384950
# 4      0.635641
# 5     -1.722946
# 6      0.662314
# 7      2.243082
# 8      1.038145
# 9      1.056863
# 10    -1.063091
# 11    -0.303877
# 12     0.907308
# 13     0.079497
# 14     0.160368
# 15    -1.287131
# 16    -0.264610
# 17     0.466478
# 18    -0.088024
# 19    -0.885154
# 20    -0.015934
# 21    -2.298082
# 22     1.159283
# 23     0.459210
# 24     0.501403
# 25    -0.345094
# 26     1.169716
# 27    -1.469169
# 28     1.205735
# 29     1.074098
#          ...
# 970   -0.389919
# 971    1.849525
# 972   -1.011254
# 973   -0.898587
# 974   -0.149644
# 975    0.492285
# 976    1.214407
# 977    1.657081
# 978   -1.628329
# 979   -0.529095
# 980   -1.626847
# 981   -0.347769
# 982    0.344582
# 983   -0.076280
# 984    0.112972
# 985    0.060915
# 986    0.214639
# 987   -0.332130
# 988   -1.391287
# 989   -0.078001
# 990   -0.719634
# 991   -0.600929
# 992   -0.880274
# 993    0.032637
# ...

# %%
col[np.abs(col)>3]
# Out:
# 247   -3.107572
# 439    3.165986
# Name: 2, dtype: float64

# %%
data[(np.abs(data)>3).any(1)]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>56</th>
#       <td>0.361678</td>
#       <td>-0.499104</td>
#       <td>-0.413899</td>
#       <td>3.282079</td>
#     </tr>
#     <tr>
#       <th>247</th>
#       <td>0.858391</td>
#       <td>-0.616298</td>
#       <td>-3.107572</td>
#       <td>0.854139</td>
#     </tr>
#     <tr>
#       <th>278</th>
#       <td>3.229730</td>
#       <td>0.149296</td>
#       <td>0.574919</td>
#       <td>-0.494882</td>
#     </tr>
#     <tr>
#       <th>333</th>
#       <td>3.105366</td>
#       <td>-0.865643</td>
# ...

# %%
data[np.abs(data)>3]

# %%
time=data[data<-0.5]

# %%
time
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>-0.711325</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-1.142579</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.507873</td>
#       <td>-0.657419</td>
#       <td>-1.113992</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>-1.787249</td>
#       <td>-1.384950</td>
#       <td>NaN</td>
# ...

# %%
data[data<-0.5]=np.sign(data)*3

# %%
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2.816496</td>
#       <td>2.002822</td>
#       <td>-3.000000</td>
#       <td>1.327157</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-3.000000</td>
#       <td>-0.432520</td>
#       <td>1.052716</td>
#       <td>0.734501</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-3.000000</td>
#       <td>-3.000000</td>
#       <td>-3.000000</td>
#       <td>1.571624</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.398692</td>
#       <td>-3.000000</td>
# ...

# %%
df=pd.DataFrame(np.arange(20).reshape((5,4)))

# %%
sampler=np.random.permutation(5)

# %%
df.iloc[sampler,:]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>12</td>
#       <td>13</td>
#       <td>14</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>16</td>
# ...

# %%
df.sample(n=3,replace=True)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>16</td>
#       <td>17</td>
#       <td>18</td>
#       <td>19</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame({
    'key':['a','b','c','b','a','c'],
    'data':range(6)
})

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data</th>
#       <th>key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>c</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>c</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data</th>
#       <th>key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>c</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>c</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2=pd.get_dummies(df['key'],prefix='key')

# %%
df2
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key_a</th>
#       <th>key_b</th>
#       <th>key_c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %%
df_with_dummy=df[['data']].join(df2)

# %%
df_with_dummy
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data</th>
#       <th>key_a</th>
#       <th>key_b</th>
#       <th>key_c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %%
len(df.columns)
# Out:
# 2

# %%
df_with_dummy.iloc[0].loc[['data','key_c']]
# Out:
# data     0
# key_c    0
# Name: 0, dtype: int32

# %%
'all'.find('l')
# Out:
# 2

# %%
string='time slfjasl  sjflsdjlf  jdslfkjl'

# %%
import re

# %%
regex=re.compile('\s+')

# %%
regex.split(string)
# Out:
# ['time', 'slfjasl', 'sjflsdjlf', 'jdslfkjl']

# %%
data={
    'Dave':'dave@google.com',
    'Steve':'steve@gmail.com',
    'Rob':'rob@gmail.com',
    'Wes':np.NAN
}

# %%
data
# Out:
# {'Dave': 'dave@google.com',
#  'Rob': 'rob@gmail.com',
#  'Steve': 'steve@gmail.com',
#  'Wes': nan}

# %%
data=pd.Series(data)

# %%
data
# Out:
# Dave     dave@google.com
# Rob        rob@gmail.com
# Steve    steve@gmail.com
# Wes                  NaN
# dtype: object

# %%
data.str.contains('gmail')
# Out:
# Dave     False
# Rob       True
# Steve     True
# Wes        NaN
# dtype: object

# %%
pattern=re.compile(r'([A-Z0-9._%+-]+)@([A-Z0-9.-]+)\.([A-Z]{2,4})')

# %%
pattern
# Out:
# re.compile(r'([A-Z0-9._%+-]+)@([A-Z0-9.-]+)\.([A-Z]{2,4})', re.UNICODE)

# %%
data.str.findall(r'([A-Z0-9._%+-]+)@([A-Z0-9.-]+)\.([A-Z]{2,4})',flags=re.IGNORECASE)
# Out:
# Dave     [(dave, google, com)]
# Rob        [(rob, gmail, com)]
# Steve    [(steve, gmail, com)]
# Wes                        NaN
# dtype: object

# %%
data
# Out:
# Dave     dave@google.com
# Rob        rob@gmail.com
# Steve    steve@gmail.com
# Wes                  NaN
# dtype: object

# %%
data
# Out:
# Dave     dave@google.com
# Rob        rob@gmail.com
# Steve    steve@gmail.com
# Wes                  NaN
# dtype: object

# %%
data[data.notnull()]
# Out:
# Dave     dave@google.com
# Rob        rob@gmail.com
# Steve    steve@gmail.com
# dtype: object

# %%
data.map(lambda x:x.upper())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-a0137ca62c17> in <module>()
# ----> 1 data.map(lambda x:x.upper())
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    2156         else:
#    2157             # arg is a function
# -> 2158             new_values = map_f(values, arg)
#    2159
#    2160         return self._constructor(new_values,
#
# pandas\_libs\src\inference.pyx in pandas._libs.lib.map_infer (pandas\_libs\lib.c:66645)()
#
# <ipython-input-79-a0137ca62c17> in <lambda>(x)
# ----> 1 data.map(lambda x:x.upper())
#
# AttributeError: 'float' object has no attribute 'upper'

# %%
data.str

# %%
for i in data.str:
# Out:
#   File "<ipython-input-82-b0ced29ef65d>", line 1
#     for i in data.str:
#                       ^
# SyntaxError: unexpected EOF while parsing

# %%
for i in data.str:
    print(i)
# Out:
# Dave       d
# Rob        r
# Steve      s
# Wes      NaN
# dtype: object
# Dave       a
# Rob        o
# Steve      t
# Wes      NaN
# dtype: object
# Dave       v
# Rob        b
# Steve      e
# Wes      NaN
# dtype: object
# Dave       e
# Rob        @
# Steve      v
# Wes      NaN
# dtype: object
# Dave       @
# Rob        g
# Steve      e
# Wes      NaN
# dtype: object
# Dave       g
# Rob        m
# Steve      @
# Wes      NaN
# dtype: object
# Dave       o
# Rob        a
# Steve      g
# Wes      NaN
# dtype: object
# Dave       o
# Rob        i
# Steve      m
# Wes      NaN
# dtype: object
# Dave       g
# Rob        l
# Steve      a
# Wes      NaN
# dtype: object
# Dave       l
# Rob        .
# Steve      i
# Wes      NaN
# dtype: object
# Dave       e
# Rob        c
# Steve      l
# Wes      NaN
# dtype: object
# Dave       .
# Rob        o
# Steve      .
# Wes      NaN
# dtype: object
# Dave       c
# Rob        m
# Steve      c
# Wes      NaN
# dtype: object
# ...

# %%
data.astype(string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-2ce73cfa70c8> in <module>()
# ----> 1 data.astype(string)
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# ...

# %%
data.map(lambda x:x.upper())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-a0137ca62c17> in <module>()
# ----> 1 data.map(lambda x:x.upper())
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    2156         else:
#    2157             # arg is a function
# -> 2158             new_values = map_f(values, arg)
#    2159
#    2160         return self._constructor(new_values,
#
# pandas\_libs\src\inference.pyx in pandas._libs.lib.map_infer (pandas\_libs\lib.c:66645)()
#
# <ipython-input-85-a0137ca62c17> in <lambda>(x)
# ----> 1 data.map(lambda x:x.upper())
#
# AttributeError: 'float' object has no attribute 'upper'

# %%
test={
    'kirito':24,
    'asuna':323,
    'xilika':32
}

# %%
test=pd.Series(test)

# %%
test.map(lambda x:x+2)
# Out:
# asuna     325
# kirito     26
# xilika     34
# dtype: int64

# %%
data.str.get(1)
# Out:
# Dave       a
# Rob        o
# Steve      t
# Wes      NaN
# dtype: object

# %%
data
# Out:
# Dave     dave@google.com
# Rob        rob@gmail.com
# Steve    steve@gmail.com
# Wes                  NaN
# dtype: object

# %%
data.str[1:]
# Out:
# Dave     ave@google.com
# Rob        ob@gmail.com
# Steve    teve@gmail.com
# Wes                 NaN
# dtype: object

# %%
data=data.str[1:]

# %%
data
# Out:
# Dave     ave@google.com
# Rob        ob@gmail.com
# Steve    teve@gmail.com
# Wes                 NaN
# dtype: object

# %%
data.str.upper()
# Out:
# Dave     AVE@GOOGLE.COM
# Rob        OB@GMAIL.COM
# Steve    TEVE@GMAIL.COM
# Wes                 NaN
# dtype: object

# %%
data.str.cat(['a'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-be0a7d2eb9b9> in <module>()
# ----> 1 data.str.cat(['a'])
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\strings.py in cat(self, others, sep, na_rep)
#    1468     def cat(self, others=None, sep=None, na_rep=None):
#    1469         data = self._orig if self._is_categorical else self._data
# -> 1470         result = str_cat(data, others=others, sep=sep, na_rep=na_rep)
#    1471         return self._wrap_result(result, use_codes=(not self._is_categorical))
#    1472
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\pandas\core\strings.py in str_cat(arr, others, sep, na_rep)
#     101         arrays = _get_array_list(arr, others)
#     102
# --> 103         n = _length_check(arrays)
#     104         masks = np.array([isnull(x) for x in arrays])
#     105         cats = None
#
# ...

# %%
data.str.count('gmail')
# Out:
# Dave     0.0
# Rob      1.0
# Steve    1.0
# Wes      NaN
# dtype: float64

# %%
data.str.extract(r'([A-Z0-9._%+-]+)@([A-Z0-9.-]+)\.([A-Z]{2,4})')
# Out:
# E:\software\anaconda\envs\analysisData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Dave</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Rob</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
# ...

# %%
data
# Out:
# Dave     ave@google.com
# Rob        ob@gmail.com
# Steve    teve@gmail.com
# Wes                 NaN
# dtype: object

# %%
data.str.repeat(4)
# Out:
# Dave     ave@google.comave@google.comave@google.comave@...
# Rob       ob@gmail.comob@gmail.comob@gmail.comob@gmail.com
# Steve    teve@gmail.comteve@gmail.comteve@gmail.comteve...
# Wes                                                    NaN
# dtype: object

# %%
data.str.replace('gmail','time')
# Out:
# Dave     ave@google.com
# Rob         ob@time.com
# Steve     teve@time.com
# Wes                 NaN
# dtype: object

# %%
import numpy as np
import pandas as pd

# %%
arr=np.array([[1,2],[3,4]])

# %%
arr
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
df=pd.DataFrame(arr,index=['a','b'],columns=['time','start'])

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>start</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>3</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.loc[df.time>1,'start']=2

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\software\anaconda\envs\data\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3123             try:
# -> 3124                 return libindex.get_value_box(s, key)
#    3125             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-54c49f426333> in <module>
#       2     if x['time']==1:
#       3         x['start']=1
# ----> 4 df.apply(f)
#
# ...

# %%
data=pd.DataFrame(np.arange(6).reshape((2,3)),
                  index=['Ohio','Colorado'],
                  columns=['one','two','three'],
                  )

# %%
data.set_index('one')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>two</th>
#       <th>three</th>
#     </tr>
#     <tr>
#       <th>one</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

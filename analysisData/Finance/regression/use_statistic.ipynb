# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
df=pd.read_excel('./hprice1.xlsx')

# %%
x=df[['sqrft','bdrms']]
y=df['price']
x=sm.add_constant(x)
# Out:
# D:\software\Anaconda\envs\data\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
model=sm.OLS(y,x)
result=model.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.632
# Model:                            OLS   Adj. R-squared:                  0.623
# Method:                 Least Squares   F-statistic:                     72.96
# Date:                Thu, 24 Oct 2019   Prob (F-statistic):           3.57e-19
# Time:                        21:49:30   Log-Likelihood:                -488.00
# No. Observations:                  88   AIC:                             982.0
# Df Residuals:                      85   BIC:                             989.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -19.3150     31.047     -0.622      0.536     -81.044      42.414
# ...

# %%
confidence_interval=result.conf_int()   #confidence interval
SSE=result.ess  #SSE
SSR=result.ssr  #SSR
SST=result.centered_tss #SST
BETA=result.params  #BETA
var=result.mse_resid    #varience

# %%
result.tvalues  #compute
# Out:
# const   -0.622129
# sqrft    9.290506
# bdrms    1.602590
# dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from math import *
def f(x):
    return abs(cos(x))**0.5+sin(2+3*x)

# %%
I=50000
a_py=range(I)

# %%
def f1(a):
    res=[]
    for x in a:
        res.append(f(x))
    return res

# %%
# %%time
f1(a_py)
# Out:
# Wall time: 36.2 ms
# [1.9092974268256817,
#  -0.2238716875184228,
#  1.6344526866452613,
#  -0.005006540051375796,
#  1.7990896504073841,
#  -0.42879803124968885,
#  1.8928280430300366,
#  0.022055044253094347,
#  1.1440031172513554,
#  0.29089755156307695,
#  1.4674351577725862,
#  -0.36165674982531304,
#  1.2149838184765536,
#  0.7939773424540544,
#  0.38748188428091246,
#  0.9951738988226787,
#  0.7162259230806519,
#  0.9204852878701615,
#  0.29104773544845997,
#  1.6310742773147104,
#  -0.1003676865958959,
#  1.5669160123260792,
#  0.10205273231620204,
#  1.6810087753287675,
#  -0.33385599696279855,
#  1.9951118479109877,
#  -0.18957570343168983,
#  1.508863127827344,
#  0.05766634949920191,
#  1.7249725967471383,
#  -0.386717486056826,
#  1.6396833570072122,
#  0.3399764150505993,
#  0.5672505554491503,
#  0.5995563388764966,
#  1.135409013836858,
#  0.31347744942721295,
#  0.7776975440570932,
#  1.2139400864950096,
#  0.1449706969011948,
#  1.3153759127217626,
# ...

# %%
a_np=np.arange(I)

# %%
# %%time
np.abs(np.cos(a_np))**0.5+np.sin(2+3*a_np)
# Out:
# Wall time: 259 ms
# array([ 1.90929743, -0.22387169,  1.63445269, ...,  1.0688799 ,
#         0.33745313,  1.41690925])

# %%
import

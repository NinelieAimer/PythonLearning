# %%
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
data=np.arange(10)

# %%
plt.plot(data)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-1f731ff0cd28> in <module>()
# ----> 1 fig,axes=plt.subplot(2,3)
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1042
#    1043     fig = gcf()
# -> 1044     a = fig.add_subplot(*args, **kwargs)
#    1045     bbox = a.bbox
#    1046     byebye = []
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1019                     self._axstack.remove(ax)
#    1020
# -> 1021             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1022
#    1023         self._axstack.add(key, a)
#
# E:\software\anaconda\envs\analysisData\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      66                 # num - 1 for converting from MATLAB to python indexing
#      67         else:
# ---> 68             raise ValueError('Illegal argument(s) to subplot: %s' % (args,))
#      69
#      70         self.update_params()
#
# ValueError: Illegal argument(s) to subplot: (2, 3)

# %%
fig=plt.figure()

# %%
ax1=fig.add_subplot(2,2,1)

# %%
ax1

# %%
plt.plot(np.random.randn(50).cumsum(),'k--')

# %%
fig=plt.subplots(2,3)

# %%
fig=plt.subplots(2,3)

# %%
fig,axes=plt.subplots(2,2,sharex=True,sharey=True)
fig

# %%
fig,axes=plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins=50,color='k',alpha=0.5)
fig.subplots_adjust(wspace=0,hspace=0)

# %%
ax=plt.subplot()

# %%
ax.plot([2,3],[2,3],'g--')

# %%
# %matplotlib inline

# %%
ax.plot([2,3],[2,3],'g--')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-5f90218d402c> in <module>()
# ----> 1 ax[0,0]
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
plt.plot(np.random.randn(30).cumsum(),'ko--')

# %%
plt.plot(np.random.randn(30).cumsum(),color='k',marker='o',linestyle='dashed')

# %%
data=np.random.rand(30).cumsum()

# %%
plt.plot(data,'k--',label='first')

# %%
# %matplotlib inline

# %%
plt.plot(data,'k--',label='first')
plt.plot(data,'k-',drawstyle='steps-post',label='steps-post')
plt.legend(loc='best')

# %%
plt.plot(data,'k-',drawstyle='steps-post',label='steps-post')

# %%
fig,ax=plt.subplots(1,1)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks([0,200,500,750,1000])
ax.set_xticklabels(['one','two','three','four','five'],rotation=30,fontsize='small')
ax.set_title('test')
ax.set_xlabel('random')

# %%
fig,ax=plt.subplots(1,1)
settings={
    'title':"test",
    'xlabel':'random',
}
ax.plot(np.random.randn(1000).cumsum(),linestyle='dashed')
ax.set(**settings)
# Out:
# [<matplotlib.text.Text at 0x23ae0a7ef28>,
#  <matplotlib.text.Text at 0x23ae0ab5198>]

# %%
fig,ax=plt.subplots(1,1)
ax.plot(np.random.randn(1000).cumsum(),'k',label='one')
ax.plot(np.random.randn(1000).cumsum(),'k--',label='two')
ax.legend(loc='best')
plt.savefig('test.svg')

# %%
s=pd.Series(np.random.randn(10).cumsum(),index=np.arange(0,100,10))
s.plot()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
series=pd.Series(np.random.randn(10).cumsum(),index=np.arange(0,100,10))
series.plot()

# %%
df=pd.DataFrame(np.random.randn(10,4).cumsum(0),
                columns=['A','B','C','D'],
                index=np.arange(0,100,10))

# %%
fig,axes=plt.subplots(2,2)
df.plot(ax=axes[0,0])

# %%
fig,axes=plt.subplots(2,1)

# %%
fig,axes=plt.subplots(2,1)
data=pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))
data.plot(kind='bar',alpha=0.7,color='k',ax=axes[1])

# %%
df=pd.DataFrame(np.random.rand(6,4),
                index=['one','two','three','four','five','six'],
                columns=pd.Index(['A','B','C','D'],name='Genus'))

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh',alpha=0.5,stacked=True)

# %%
df.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Genus</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>6.000000</td>
#       <td>6.000000</td>
#       <td>6.000000</td>
#       <td>6.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.559047</td>
#       <td>0.462050</td>
#       <td>0.532839</td>
#       <td>0.543014</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.298934</td>
#       <td>0.314900</td>
#       <td>0.179539</td>
#       <td>0.348330</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.237992</td>
#       <td>0.078911</td>
#       <td>0.246323</td>
#       <td>0.051540</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>0.307467</td>
#       <td>0.234228</td>
#       <td>0.510350</td>
#       <td>0.293352</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>0.554147</td>
#       <td>0.443057</td>
#       <td>0.527099</td>
#       <td>0.634248</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>0.761448</td>
#       <td>0.699980</td>
#       <td>0.569404</td>
#       <td>0.764341</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>0.952208</td>
#       <td>0.857036</td>
#       <td>0.808239</td>
#       <td>0.950621</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.describe().plot(kind='bar')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
np.random.seed(1000)
y=np.random.standard_normal((1000,2))

# %%
x=range(len(y))

# %%
plt.plot(x,y)

# %%
plt.plot(y)

# %%
a=[1,2,3,4,5,6]

# %%
a=np.array(a)

# %%
a.cumsum()
# Out:
# array([ 1,  3,  6, 10, 15, 21], dtype=int32)

# %%
plt.plot(y,'yo--')
plt.grid(True)

# %%
c=np.random.randint(0,10,len(y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8c344d7fd35f> in <module>
# ----> 1 c=np.random.randint(0,10,len(y))
#
# NameError: name 'np' is not defined

# %%
plt.figure(figsize=(7,5))
plt.scatter(y[:,0],y[:,1],c=c,marker='o')
plt.colorbar()
plt.xlabel('1st')
plt.ylabel('2end')
plt.title('scatter plot')
# Out:
# Text(0.5,1,'scatter plot')

# %%
y
# Out:
# array([-0.8044583 ,  0.32093155, -0.02548288,  0.64432383, -0.30079667,
#         0.38947455, -0.1074373 , -0.47998308,  0.5950355 , -0.46466753,
#         0.66728131, -0.80611561, -1.19606983, -0.40596016, -0.18237734,
#         0.10319289, -0.13842199,  0.70569237,  1.27179528, -0.98674733])

# %%
plt.figure(figsize=(7,4))
plt.hist(y,label=['1st','2nd'],bins=25,stacked=True)
plt.grid(True)
plt.legend(loc='best')
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('test')
# Out:
# Text(0.5,1,'test')

# %%
import pandas as pd

# %%
df=pd.DataFrame(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2ca819d51517> in <module>
# ----> 1 df=pd.DataFrame(y)
#
# NameError: name 'y' is not defined

# %%
plt.figure(figsize=(7,4))
plt.hist(df,label=['1st','2nd'],bins=25,stacked=True)
plt.grid(True)
plt.legend(loc='best')
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('test')

# %%
import numpy as np
y=np.random.standard_normal((1000,2))
c=np.random.randint(0,10,(1000,2))

# %%
c
# Out:
# array([[7, 4],
#        [4, 7],
#        [5, 3],
#        ...,
#        [8, 4],
#        [4, 2],
#        [4, 7]])

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots(figsize=(7,4))
ax.boxplot(y)
ax.set_xticklabels(['1st','2nd'])
# Out:
# [Text(0,0,'1st'), Text(0,0,'2nd')]

# %%
import matplotlib.finance as mpf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-c353be57926a> in <module>
# ----> 1 import matplotlib.finance as mpf
#
# ModuleNotFoundError: No module named 'matplotlib.finance'

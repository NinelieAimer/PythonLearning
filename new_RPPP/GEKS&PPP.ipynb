# %%
import numpy as np
import pandas as pd
import os

# %%
bas_ppp=pd.read_excel('final_vision.xlsx')
dirname=os.getcwd()
file_list=os.listdir(dirname+'\\input_data')

# %%
for file in file_list:
    if '权重' in file:
        weight=pd.read_excel('./input_data/'+file)
        break
